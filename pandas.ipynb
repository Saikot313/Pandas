# %%
#pip install pandas

# %%
import pandas as pd

# %%
a = [1, 2, 3, 4, 5]
df =  pd.Series(a)
print(df)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 5 entries, 0 to 4
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      int64
# dtypes: int64(1)
# memory usage: 172.0 bytes

# %%
df.describe()
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %%
a = {"name": "Saikot","age": 25, "city": "Rajshahi"}
df =  pd.Series(a)
print(df)
# Out:
# name      Saikot
# age           25
# city    Rajshahi
# dtype: object

# %%
a = {"name":["Saikot","Sakib","Alvi"], "age": [25,26,26], "city": ["Rajshahi","Dhaka","Khulna"]}
df =  pd.Series(a)
print(df)
# Out:
# name        [Saikot, Sakib, Alvi]
# age                  [25, 26, 26]
# city    [Rajshahi, Dhaka, Khulna]
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.Series'>
# Index: 3 entries, name to city
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 3 non-null      object
# dtypes: object(1)
# memory usage: 48.0+ bytes

# %%
a = {"n1": ["Saikot","Sakib"],
     "n2": ["Alvi","Saef"],
     "n3": ["Maruf","Mridha"]
     }

df = pd.Series(a,index=["n1","n2","n3"])
df
# Out:
# n1    [Saikot, Sakib]
# n2       [Alvi, Saef]
# n3    [Maruf, Mridha]
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.Series'>
# Index: 3 entries, n1 to n3
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 3 non-null      object
# dtypes: object(1)
# memory usage: 156.0+ bytes

# %%
df.head()
# Out:
# n1    [Saikot, Sakib]
# n2       [Alvi, Saef]
# n3    [Maruf, Mridha]
# dtype: object

# %%
a = [1, 2, 3, 4, 5]
df =  pd.DataFrame(a)
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5 non-null      int64
# dtypes: int64(1)
# memory usage: 172.0 bytes

# %%
a = [1, 2, 3, 4, 5]
df =  pd.DataFrame(a,columns= ["Numbers"])
print(df)
# Out:
#    Numbers
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Numbers  5 non-null      int64
# dtypes: int64(1)
# memory usage: 172.0 bytes

# %% [markdown]
# 2 Dimentional Data

# %%
a = [["Name","Age","Profession"],["Saikot",26,"Student"]]
df =  pd.DataFrame(a, columns=["Name","Age","Profession"])
print(df)
# Out:
#      Name  Age  Profession
# 0    Name  Age  Profession
# 1  Saikot   26     Student

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        2 non-null      str
#  1   Age         2 non-null      object
#  2   Profession  2 non-null      str
# dtypes: object(1), str(2)
# memory usage: 180.0+ bytes

# %%
a = {"Name": ["Saikot","Sakib","Alvi"],
     "Age": [26,27,28],
     "Profession": ["Student","Job Holder","Student"]
     }

df = pd.DataFrame(a,index=["1","2","3"])
df
# Out:
#      Name  Age  Profession
# 1  Saikot   26     Student
# 2   Sakib   27  Job Holder
# 3    Alvi   28     Student

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3 entries, 1 to 3
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        3 non-null      str
#  1   Age         3 non-null      int64
#  2   Profession  3 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#         Age
# count   3.0
# mean   27.0
# std     1.0
# min    26.0
# 25%    26.5
# 50%    27.0
# 75%    27.5
# max    28.0

# %%
a = {"Name": ["Saikot","Sakib","Saef"],
     "Age": [26,27,28],
     "Profession": ["Student","Student","Teacher"]
    }

df = pd.DataFrame(a)
df
# Out:
#      Name  Age Profession
# 0  Saikot   26    Student
# 1   Sakib   27    Student
# 2    Saef   28    Teacher

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        3 non-null      str
#  1   Age         3 non-null      int64
#  2   Profession  3 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 204.0 bytes

# %%
a = {"Name": ["Saikot","Sakib","Saef"],
     "Age": [26,27,28],
     "Profession": ["Student","Student","Teacher"]
    }

df = pd.DataFrame(a)
df
# Out:
#      Name  Age Profession
# 0  Saikot   26    Student
# 1   Sakib   27    Student
# 2    Saef   28    Teacher

# %%
df.rename({"Name":"col1","Age":"col2","Profession":"Col3"})
# Out:
#      Name  Age Profession
# 0  Saikot   26    Student
# 1   Sakib   27    Student
# 2    Saef   28    Teacher

# %%
df.rename({"Name":"col1","Age":"col2","Profession":"Col3"},axis=1)
# Out:
#      col1  col2     Col3
# 0  Saikot    26  Student
# 1   Sakib    27  Student
# 2    Saef    28  Teacher

# %%
df=df.rename({"Name":"col1","Age":"col2","Profession":"Col3"},axis=1)

# %%
df
# Out:
#      col1  col2     Col3
# 0  Saikot    26  Student
# 1   Sakib    27  Student
# 2    Saef    28  Teacher

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    3 non-null      str
#  1   col2    3 non-null      int64
#  2   Col3    3 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 204.0 bytes

# %%
df = df.rename({"col1":"Name","col2":"Age","Col3":"Profession"},axis=1)

# %%
df
# Out:
#      Name  Age Profession
# 0  Saikot   26    Student
# 1   Sakib   27    Student
# 2    Saef   28    Teacher

# %%
data = {
    "City": ["Dhaka","Dhaka","Dhaka",
             "Khulna","Khulna","Khulna"],
    "Day": ["Day1","Day2","Day3",
            "Day1","Day2","Day3"],
    "Temperature": [30,31,29,32,33,31]
}

df = pd.DataFrame(data)

print(df)
# Out:
#      City   Day  Temperature
# 0   Dhaka  Day1           30
# 1   Dhaka  Day2           31
# 2   Dhaka  Day3           29
# 3  Khulna  Day1           32
# 4  Khulna  Day2           33
# 5  Khulna  Day3           31

# %%
df.ndim
# Out:
# 2

# %%
a = {"Name": ["Saikot","Sakib","Saef"],
     "Age": [26,None,28],
     "Profession": ["Student",None,"Teacher"]
    }

df = pd.DataFrame(a)
df
# Out:
#      Name   Age Profession
# 0  Saikot  26.0    Student
# 1   Sakib   NaN        NaN
# 2    Saef  28.0    Teacher

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        3 non-null      str
#  1   Age         2 non-null      float64
#  2   Profession  2 non-null      str
# dtypes: float64(1), str(2)
# memory usage: 204.0 bytes

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# [] means one dimentional data,
# [[]] means two dimentional data,
# [[[]]] meas three dimentional data

# %%
df[["Age"]]
# Out:
#     Age
# 0  26.0
# 1   NaN
# 2  28.0

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        3 non-null      str
#  1   Age         2 non-null      float64
#  2   Profession  2 non-null      str
# dtypes: float64(1), str(2)
# memory usage: 204.0 bytes

# %%
df[["Age"]].astype("int32")
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df[["Age"]].astype("int32")
#
# File c:\Users\SAIKOT\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File c:\Users\SAIKOT\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# --> 611     return self.apply("astype", dtype=dtype, errors=errors)
#
# File c:\Users\SAIKOT\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File c:\Users\SAIKOT\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\blocks.py:607, in Block.astype(self, dtype, errors, squeeze)
#     604         raise ValueError("Can not squeeze with more than one column.")
#     605     values = values[0, :]  # type: ignore[call-overload]
# --> 607 new_values = astype_array_safe(values, dtype, errors=errors)
#     609 new_values = maybe_coerce_values(new_values)
#     611 refs = None
#
# File c:\Users\SAIKOT\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\dtypes\astype.py:240, in astype_array_safe(values, dtype, copy, errors)
#     237     dtype = dtype.numpy_dtype
#     239 try:
# --> 240     new_values = astype_array(values, dtype, copy=copy)
#     241 except (ValueError, TypeError):
#     242     # e.g. _astype_nansafe can fail on object-dtype of strings
#     243     #  trying to convert to float
#     244     if errors == "ignore":
#
# File c:\Users\SAIKOT\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\dtypes\astype.py:185, in astype_array(values, dtype, copy)
#     182     values = values.astype(dtype, copy=copy)
#     184 else:
# --> 185     values = _astype_nansafe(values, dtype, copy=copy)
#     187 # in pandas we don't store numpy str dtypes, so convert to object
#     188 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\SAIKOT\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\dtypes\astype.py:102, in _astype_nansafe(arr, dtype, copy, skipna)
#      97     return lib.ensure_string_array(
#      98         arr, skipna=skipna, convert_na_value=False
#      99     ).reshape(shape)
#     101 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 102     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     104 elif arr.dtype == object:
#     105     # if we have a datetime/timedelta array of objects
#     106     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     108     if lib.is_np_dtype(dtype, "M"):
#
# File c:\Users\SAIKOT\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\dtypes\astype.py:146, in _astype_float_to_int_nansafe(values, dtype, copy)
#     142 """
#     143 astype with a check preventing converting NaN to a meaningless integer value.
#     144 """
#     145 if not np.isfinite(values).all():
# --> 146     raise IntCastingNaNError(
#     147         "Cannot convert non-finite values (NA or inf) to integer."
#     148         "Replace or remove non-finite values or cast to an integer type"
#     149         "that supports these values (e.g. 'Int64')"
#     150     )
#     151 if dtype.kind == "u":
#     152     # GH#45151
#     153     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer.Replace or remove non-finite values or cast to an integer typethat supports these values (e.g. 'Int64')

# %%
a = {"Name": ["Saikot","Sakib","Saef"],
     "Salary": [25000,30000,80000],
     "Profession": ["Student","Student","Teacher"]
    }

df = pd.DataFrame(a)
df
# Out:
#      Name  Salary Profession
# 0  Saikot   25000    Student
# 1   Sakib   30000    Student
# 2    Saef   80000    Teacher

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        3 non-null      str
#  1   Salary      3 non-null      int64
#  2   Profession  3 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 204.0 bytes

# %%
df[["Salary"]].astype("int64")
# Out:
#    Salary
# 0   25000
# 1   30000
# 2   80000

# %%
df[["Salary"]].astype("int32")
# Out:
#    Salary
# 0   25000
# 1   30000
# 2   80000

# %%
df[["Salary"]].astype("int16")
# Out:
#    Salary
# 0   25000
# 1   30000
# 2   14464
