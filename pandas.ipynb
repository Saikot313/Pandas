# %%
#pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
a = [1, 2, 3, 4, 5]
df =  pd.Series(a)
print(df)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 5 entries, 0 to 4
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      int64
# dtypes: int64(1)
# memory usage: 172.0 bytes

# %%
a = (1, 2, 3, 4, 5)
df =  pd.Series(a)
print(df)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
a = {1, 2, 3, 4, 5}
df =  pd.Series(a)
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 a = {1, 2, 3, 4, 5}
# ----> 2 df =  pd.Series(a)
#       3 print(df)
#
# File c:\Users\SAIKOT\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\series.py:514, in Series.__init__(self, data, index, dtype, name, copy)
#     512         data = data.copy(deep=True)
#     513 else:
# --> 514     data = sanitize_array(data, index, dtype, copy)
#     515     data = SingleBlockManager.from_array(data, index, refs=refs)
#     517 NDFrame.__init__(self, data)
#
# File c:\Users\SAIKOT\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\construction.py:656, in sanitize_array(data, index, dtype, copy, allow_2d)
#     647     return sanitize_array(
#     648         data,
#     649         index=index,
#    (...)    652         allow_2d=allow_2d,
#     653     )
#     655 else:
# ...

# %%
a = {"name": "Saikot","age": 25, "city": "Rajshahi"}
df =  pd.Series(a)
print(df)
# Out:
# name      Saikot
# age           25
# city    Rajshahi
# dtype: object

# %%
a = {"name":["Saikot","Sakib","Alvi"], "age": [25,26,26], "city": ["Rajshahi","Dhaka","Khulna"]}
df =  pd.Series(a)
print(df)
# Out:
# name        [Saikot, Sakib, Alvi]
# age                  [25, 26, 26]
# city    [Rajshahi, Dhaka, Khulna]
# dtype: object
